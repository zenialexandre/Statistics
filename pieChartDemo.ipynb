# %% [markdown]
# <a href="https://colab.research.google.com/github/zenialexandre/Data-Science/blob/main/pieChartDemo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# job data in percentile
job_data = ['40', '20', '17', '8', '5', '10']

# define the label as different department
labels = 'IT', 'Finance', 'Marketing', 'Admin', 'HR', 'Operations'

# explode the 1st slice (IT)
explode = (0.05, 0, 0, 0, 0, 0)

# draw the pie chart and set the params
plt.pie(job_data, labels=labels, explode=explode)
plt.show()
